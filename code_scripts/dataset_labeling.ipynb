# %%
import pandas as pd

# %%
########################################################
###         HELPER FUNCTIONS FOR LABELING            ###
########################################################

def assign_destination(destination: str) -> int:
    if destination == "ff:ff:ff:ff:ff:ff":
        return 1
    else:
        return 0


def check_null_value(string_to_check: str) -> str:
    if pd.isna(string_to_check):
        return ""
    else:
        return string_to_check


def extract_rssi(rssi_string: str) -> int:
    rssi_value = rssi_string.replace(" dBm", "")
    return int(rssi_value)


def assign_device(device: str, source: str) -> str:
    # The source "e4:22:a6:0d:7c:4b" is uniquely assigned to the buds and was extensively tested
    if device == "empty" and source == "e4:22:a6:0d:7c:4b":
        return "Buds"
    elif device in ["Phone", "Phone Scan", "Phone Google"]:
        return "Phone"
    else:
        return device


def encode_company_id(company: str, source: str, service_data: str) -> str:
    # Defined, but not named company identifiers f.e. 0x34f5
    if str(company).startswith("0x") and len(company) == 6:
        return "Unknown"
    # Assign the Buds "Anonymous" source the company Samsung
    elif pd.isna(company) and source == "Anonymous":
        return "Samsung Electronics Co. Ltd."
    elif pd.isna(company) and str(service_data).startswith("4a17235"):
        return "Samsung Electronics Co. Ltd."
    elif pd.isna(company):
        return "Undefined"
    else:
        return company


def extract_time(delta_string: str) -> int:
    if pd.isna(delta_string):
        return 0
    else:
        return int(delta_string.replace("\\302\\265s", ""))


def check_company_id_existence(company_id: str) -> int:
    if company_id == "Undefined":
        return 0
    else:
        return 1


def extract_length(entry_to_exctract: str) -> int:
    if pd.isna(entry_to_exctract):
        return 0
    else:
        return len(entry_to_exctract)


def is_adv_channel(channel: int) -> bool:
    if channel in [37, 38, 39]:
        return True
    else:
        return False


def check_entry_existence(entry_to_check: str) -> int:
    if pd.isna(entry_to_check):
        return 0
    else:
        return 1

# %%
# Read the input CSV file and rename some columns
def read_data_to_df(file_name: str) -> pd.DataFrame:
    dataset_df = pd.read_csv(file_name, encoding='ISO-8859-1')
    a = dataset_df.columns
    dataset_df.columns = dataset_df.columns.str.replace("Packet time (start to end)", "packet_start_end")
    dataset_df.columns = dataset_df.columns.str.replace("Delta time (end to start)", "delta_end_start")
    dataset_df.columns = dataset_df.columns.str.replace("Delta time (start to start)", "delta_start_start")
    dataset_df.columns = dataset_df.columns.str.replace(" ", "_")
    dataset_df.columns = dataset_df.columns.str.replace("Test", "Device")
    return dataset_df

def initialize_source_dictionaries(all_unique_sources: list) -> None:
    for source in all_unique_sources:
        if str(source) != "nan":
            source_dictionaries[source] = {}
            source_dictionaries[source]["count"] = 0
            source_dictionaries[source]["malformed_count"] = 0
            source_dictionaries[source]["highest_rssi"] = 0
            source_dictionaries[source]["lowest_rssi"] = -100
            source_dictionaries[source]["first_occurence"] = -1
            source_dictionaries[source]["last_occurence"] = 0
            source_dictionaries[source]["device"] = "empty"
            source_dictionaries[source]["sub_device"] = ""

# %%
# Assign values for each row with either simple transformations or direct value usage
def fill_labelled_columns(packet_data: tuple, device: str, sub_device: str):

    row_data = {
        "time": packet_data.Time,
        "source": packet_data.Source,
        "destination": packet_data.Destination,
        "is_broadcast": assign_destination(packet_data.Destination),
        "length": packet_data.Length,
        "info": packet_data.Info,
        "rssi": extract_rssi(packet_data.RSSI),
        "company_id": encode_company_id(packet_data.Company_ID, packet_data.Source, packet_data.Service_Data),
        "has_company_id": check_company_id_existence(encode_company_id(packet_data.Company_ID, packet_data.Source, packet_data.Service_Data)),
        "channel": packet_data.Channel,
        "is_adv_channel": is_adv_channel(packet_data.Channel),
        "device_name": check_null_value(packet_data.Device_Name),
        "uuid16": check_null_value(packet_data.UUID16),
        "has_uuid16": check_entry_existence(packet_data.UUID16),
        "len_uuid16": extract_length(packet_data.UUID16),
        "uuid128": check_null_value(packet_data.UUID128),
        "has_uuid128": check_entry_existence(packet_data.UUID128),
        "data": check_null_value(packet_data.Data),
        "len_data": extract_length(packet_data.Data),
        "ad_type": check_null_value(packet_data.AD_Type),
        "len_ad_type": extract_length(packet_data.Data),
        "service_data": check_null_value(packet_data.Service_Data),
        "len_service_data": extract_length(packet_data.Service_Data),
        "crc": check_null_value(packet_data.CRC),
        "labelled_device": assign_device(device, packet_data.Source),
        "sublabel_device": sub_device,
        "time_start_end": extract_time(packet_data.packet_start_end),
        "delta_end_start": extract_time(packet_data.delta_end_start),
        "delta_start_start": extract_time(packet_data.delta_start_start)
    }

    # To ensure labeling quality, phone-based labels which do not a valid company_id are labeled empty
    # Valid company_ids include: ["Samsung Electronics Co. Ltd.", "Undefined", "Unknown"]
    # Invalid company_ids include: Any other company such as "Apple", "Conneqtech B.V." etc.
    if row_data["labelled_device"] in ['Phone'] and row_data["company_id"] not in phone_companies:
        row_data["labelled_device"] = "empty"
        row_data["sublabel_device"] = "empty"

    return row_data

# %%
# Main raw dataset input parsing method
def parse_dataframe(input_dataframe: pd.DataFrame):
    # Define some helper variables for tracking of outliers
    nan_discarded_counter = 0
    malformed_discarded_counter = 0
    smart_tag_list = []
    buds_list = []
    phone_list = []
    phone_data = []

    for row in input_dataframe.itertuples(index=False):
        # Skip the source "nan" and keep track of packets
        if str(row.Source) == "nan":
            nan_discarded_counter += 1
            continue

        # Any source != "nan" is valid, therefore we can increase the counter of source packets here
        source_dictionaries[row.Source]["count"] += 1

        # Skip malformed packets and keep track of occurrences
        if "Malformed Packet" in row.Info:
            source_dictionaries[row.Source]["malformed_count"] += 1
            malformed_discarded_counter += 1
            continue

        current_rssi = int(row.RSSI.split(" ")[0])

        # Assign and overwrite source dictionary values with the current row
        if source_dictionaries[row.Source]["first_occurence"] == -1:
            source_dictionaries[row.Source]["first_occurence"] = row.Time
        if row.Time > source_dictionaries[row.Source]["last_occurence"]:
            source_dictionaries[row.Source]["last_occurence"] = row.Time
        if current_rssi > source_dictionaries[row.Source]["lowest_rssi"]:
            source_dictionaries[row.Source]["lowest_rssi"] = current_rssi
        if current_rssi < source_dictionaries[row.Source]["highest_rssi"]:
            source_dictionaries[row.Source]["highest_rssi"] = current_rssi

        # Label conditions for the buds
        if row.Source == "Anonymous":
            buds_list.append(row.Source)
            source_dictionaries[row.Source]["device"] = "Buds"
            source_dictionaries[row.Source]["sub_device"] = "Buds"
        if row.Device_Name == "Joel's Buds2 Pro" or row.Device_Name == "Buds2 Pro":
            buds_list.append(row.Source)
            source_dictionaries[row.Source]["device"] = "Buds"
            source_dictionaries[row.Source]["sub_device"] = "Buds"

        # Label conditions for the smart tag
        if row.Device_Name == "Smart Tag":
            smart_tag_list.append(row.Source)
            source_dictionaries[row.Source]["device"] = "Smart Tag"
            source_dictionaries[row.Source]["sub_device"] = "Smart Tag"
        
        # Label conditions for the phone
        if row.UUID16 == "Google LLC" and row.Length == 63:
            source_dictionaries[row.Source]["device"] = "Phone"
            source_dictionaries[row.Source]["sub_device"] = "Phone Google"
        if str(row.Data).startswith("021861"):
            phone_list.append(row.Source)
            phone_data.append(row.Data)
            source_dictionaries[row.Source]["device"] = "Phone"
            source_dictionaries[row.Source]["sub_device"] = "Phone Phone"
        if row.Info == "SCAN_REQ" and row.Length == 38:
            source_dictionaries[row.Source]["device"] = "Phone"
            source_dictionaries[row.Source]["sub_device"] = "Phone Scan"

        # After assigning all values, create a transformed row for the final list of rows
        row_data = fill_labelled_columns(row, source_dictionaries[row.Source]["device"], source_dictionaries[row.Source]["sub_device"])
        final_list.append(row_data)

    return nan_discarded_counter, malformed_discarded_counter

# %%
def find_empty_and_malformed_sources():
    only_malformed_sources = []
    empty_sources = []

    for key in source_dictionaries.keys():
        count = source_dictionaries[key]["count"]
        malformed_count = source_dictionaries[key]["malformed_count"]
        device = source_dictionaries[key]["device"]

        # If there are only malformed packets, a source is "malformed-only"
        if (count - malformed_count) == 0:
            only_malformed_sources.append(key)
        
        # Get all sources which are not part of the target group (and contain at least 1 valid packet)
        if (count - malformed_count) != 0 and device == "empty":
            empty_sources.append(key)

    print(f"Only Malformed Sources: {len(only_malformed_sources)}")
    print(f"Empty Sources: {len(empty_sources)}")

    return only_malformed_sources, empty_sources

# Recursively reassign sources due to non-deterministic BLE packet contents
# --> Extensively described in the thesis
def reassign_sources():
    empty_occurrences = 0
    new_final_list = []

    for row_dict in final_list:
        if row_dict["labelled_device"] == "empty" and row_dict["company_id"] in phone_companies:
            current_source = row_dict["source"]
            row_dict["labelled_device"] = source_dictionaries[current_source]["device"]

        if row_dict["labelled_device"] != "empty":
            new_final_list.append(row_dict)
        else:
            new_final_list.append(row_dict)
            empty_occurrences += 1

    return empty_occurrences, new_final_list

# %%
# In case of several label assignments for source (may happen rarely), assign the source its majority label
# For example: A source has 700 packets labeled "Phone" and 3 packets labeled "empty" --> all packets get assigned "Phone"
def get_majority_label(group):
    majority_label = group['labelled_device'].mode()[0]
    group['labelled_device'] = majority_label
    return group

# Create the final dataframe based on the final_list rows and make sure all sources only have 1 label
def create_labelled_dataframe(entry_list: list):
    new_df = pd.DataFrame(data=entry_list, columns=list((final_list[0].keys())))
    relabeled_dataframe = new_df.groupby('source').apply(get_majority_label).reset_index(drop=True)
    return relabeled_dataframe

# Write the dataframe to a file
def write_new_dataframe(file_to_write: str, df_to_write: pd.DataFrame):
    df_to_write.to_csv(file_to_write, encoding='utf-8', index=False)
    print(f"New CSV written as: {file_to_write}")

# Extract information about the sources of a label
def info_extractor(df_input: pd.DataFrame, wanted_label: str):
    seen_sources = {}
    for row in df_input.itertuples(index=False):
        if row.source not in seen_sources.keys() and row.sublabel_device == wanted_label:
            seen_sources[row.source] = {}
            seen_sources[row.source]["first"] = row.time
            seen_sources[row.source]["last"] = row.time
            seen_sources[row.source]["count"] = source_dictionaries[row.source]["count"]
            continue
        if row.source in seen_sources.keys() and row.sublabel_device == wanted_label:
            if seen_sources[row.source]["last"] < row.time:
                seen_sources[row.source]["last"] = row.time

    return seen_sources

# %%
########################################################
###                   MAIN SCRIPT                    ###
########################################################

# Global variables
final_list = []
source_dictionaries = {}
phone_companies = ["Samsung Electronics Co. Ltd.", "Undefined", "Unknown"]
undefined_list = []

# Setup all lists, dictionaries and the labeled dataframe
raw_dataframe = read_data_to_df("../data/interference_apartement_6h_4.2.csv")
all_sources = raw_dataframe["Source"].unique()
initialize_source_dictionaries(all_sources)
nan_counter, malformed_counter = parse_dataframe(raw_dataframe)
malformed_list, empty_list = find_empty_and_malformed_sources()
empty_counter, filtered_list = reassign_sources()
labelled_dataframe = create_labelled_dataframe(filtered_list)
relevant_sources = labelled_dataframe["source"].unique()
print(labelled_dataframe["sublabel_device"].value_counts())

# Extract all labels based on sources
phone_google_sources = info_extractor(labelled_dataframe, "Phone Google")
phone_scan_sources = info_extractor(labelled_dataframe, "Phone Scan")
phone_phone_sources = info_extractor(labelled_dataframe, "Phone Phone")
phone_sources = phone_google_sources | phone_scan_sources | phone_phone_sources
bud_sources = info_extractor(labelled_dataframe, "Buds")
smart_tag_sources = info_extractor(labelled_dataframe, "Smart Tag")

# For the phone sources, labeling needs to be closely inspected and adjusted
# Therefore, each source is filtered according to some criteria and re-labeled if needed
for label in ["Phone Scan", "Phone Google", "Phone Phone"]:
    actual_phone_sources = []
    for source in phone_sources.keys():
        first = round(phone_sources[source]["first"], 3)
        last = round(phone_sources[source]["last"], 3)
        count = phone_sources[source]["count"]
        max_rssi = source_dictionaries[source]["highest_rssi"]
        low_rssi = source_dictionaries[source]["lowest_rssi"]

        # Find Phone Google labeled sources
        if label == "Phone Google" and source_dictionaries[source]["sub_device"] == label:
            # These conditions are dependent on the dataset
            # For the Apartment Dataset 1+3 and University Datset 1 --> max_rssi >= -70
            # For the Apartment Dataset 2 --> max_rssi >= -80
            if count > 30 and max_rssi >= -70:
                print(f"Source: {source}, First: {first}, Last: {last}, Count: {count}, Highest RSSI:{max_rssi}, Lowest RSSI:{low_rssi} Label: {label}")
                actual_phone_sources.append(source)

        # Find Phone Scan labeled sources
        if label == "Phone Scan" and source_dictionaries[source]["sub_device"] == label:
            # These conditions are dependent on the dataset
            # For the Apartment Dataset 1+3 and University Datset 1 --> max_rssi >= -40
            # For the Apartment Dataset 2 --> max_rssi >= -58
            if max_rssi >= -40:
                print(f"Source: {source}, First: {first}, Last: {last}, Count: {count}, Highest RSSI:{max_rssi}, Lowest RSSI:{low_rssi} Label: {label}")
                actual_phone_sources.append(source)

        # Find Phone Phone labeled sources
        if label == "Phone Phone" and source_dictionaries[source]["sub_device"] == label:
            # These conditions are dependent on the dataset
            # For the Apartment Dataset 1+3 and University Datset 1 --> low_rssi >= -50
            # For the Apartment Dataset 2 --> low_rssi >= -65
            if low_rssi >= -50:
                # Only consider packets with count > 3 because otherwise a lot of potentially noisy data is introduced
                # Sacrifice some minor labeling accuracy for increased dataset quality
                if count > 3:
                    print(f"Source: {source}, First: {first}, Last: {last}, Count: {count}, Highest RSSI:{max_rssi}, Lowest RSSI:{low_rssi} Label: {label}")
                    pass
                actual_phone_sources.append(source)

    # Reassign the labels based on the above conditions
    current_phone_sources = labelled_dataframe[labelled_dataframe['sublabel_device'] == label]["source"]
    diff_sources = set(current_phone_sources) - set(actual_phone_sources)
    labelled_dataframe.loc[labelled_dataframe['source'].isin(diff_sources), 'labelled_device'] = 'empty'

# Print information about dataframe length
print("--------------------------------------------------")
print("FINAL DATAFRAME\n")
print(f"Length Raw Dataframe: {len(raw_dataframe)}")
print(f"Length Final Dataframe: {len(labelled_dataframe)}")
print(f"Removed: {malformed_counter+nan_counter}, Diff: {len(raw_dataframe)-len(labelled_dataframe)}")

# Uncomment the line below to write the file
# write_new_dataframe("int_uni_1.csv", labelled_dataframe)
# Out:
# Only Malformed Sources: 25836
# Empty Sources: 15933
# C:\Users\Schoggi\AppData\Local\Temp\ipykernel_13148\1988354439.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   relabeled_dataframe = new_df.groupby('source').apply(get_majority_label).reset_index(drop=True)
# sublabel_device
#                 1353459
# Buds             673585
# Phone Phone      337002
# Phone Scan       129410
# Phone Google      51472
# Smart Tag         26089
# empty               110
# Name: count, dtype: int64
# Source: 41:36:ff:e3:79:d4, First: 14304.659, Last: 14626.201, Count: 131, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 42:68:98:3c:fa:ad, First: 6053.368, Last: 6737.097, Count: 437, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 43:15:33:00:7a:0f, First: 11313.76, Last: 11819.429, Count: 277, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 45:c5:15:26:f1:f7, First: 1916.491, Last: 2263.35, Count: 288, Highest RSSI:-24, Lowest RSSI:-22 Label: Phone Scan
# Source: 46:61:f0:f7:18:00, First: 20071.958, Last: 20411.952, Count: 134, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 47:86:7d:93:45:6d, First: 17648.596, Last: 18347.96, Count: 331, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 48:19:7a:41:0a:97, First: 17302.372, Last: 17646.194, Count: 161, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 48:6c:cc:45:da:e1, First: 7159.592, Last: 7606.044, Count: 323, Highest RSSI:-24, Lowest RSSI:-22 Label: Phone Scan
# Source: 49:31:77:e8:14:5f, First: 8742.664, Last: 9192.326, Count: 228, Highest RSSI:-26, Lowest RSSI:-22 Label: Phone Scan
# Source: 4c:51:31:0d:92:35, First: 3734.674, Last: 4355.655, Count: 516, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 4c:61:89:c5:98:d3, First: 656.218, Last: 1043.481, Count: 333, Highest RSSI:-24, Lowest RSSI:-21 Label: Phone Scan
# Source: 4d:81:ce:28:ad:73, First: 4358.73, Last: 4708.722, Count: 345, Highest RSSI:-24, Lowest RSSI:-22 Label: Phone Scan
# Source: 4f:59:00:8c:79:9e, First: 15017.54, Last: 15420.327, Count: 197, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 4f:d1:a3:dd:48:8a, First: 21546.257, Last: 21671.35, Count: 51, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 50:2e:f1:55:08:e3, First: 10112.405, Last: 10481.046, Count: 172, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 50:38:27:66:4f:5e, First: 7608.665, Last: 8133.504, Count: 269, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 52:25:2c:fd:23:5d, First: 16249.443, Last: 16742.495, Count: 219, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 54:c2:c1:3d:3c:5d, First: 15422.514, Last: 15834.768, Count: 202, Highest RSSI:-28, Lowest RSSI:-22 Label: Phone Scan
# Source: 58:b7:e4:59:bc:30, First: 11821.641, Last: 12411.902, Count: 363, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 59:12:11:21:d4:68, First: 5578.793, Last: 6050.362, Count: 326, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 5a:02:59:14:87:cb, First: 13625.249, Last: 14000.066, Count: 191, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 5a:5a:e3:cd:1f:65, First: 12811.59, Last: 13267.219, Count: 224, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 5b:5e:33:b9:c3:fb, First: 1044.847, Last: 1441.36, Count: 322, Highest RSSI:-24, Lowest RSSI:-22 Label: Phone Scan
# Source: 5c:98:6a:16:c7:6a, First: 18815.581, Last: 19221.584, Count: 168, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 5f:31:2e:53:41:c4, First: 14000.516, Last: 14303.182, Count: 134, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 5f:48:86:72:5a:ba, First: 13268.212, Last: 13623.987, Count: 174, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 5f:5b:47:60:81:ce, First: 8133.823, Last: 8739.562, Count: 328, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 5f:fd:2b:4a:06:af, First: 9192.588, Last: 9667.378, Count: 207, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 62:d8:3c:be:a7:0e, First: 20419.476, Last: 21062.621, Count: 250, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 63:8f:ca:c2:55:45, First: 10481.595, Last: 10878.531, Count: 193, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 66:ad:36:27:c0:65, First: 6739.002, Last: 7157.311, Count: 296, Highest RSSI:-28, Lowest RSSI:-22 Label: Phone Scan
# Source: 69:27:8e:10:77:19, First: 18348.182, Last: 18813.652, Count: 213, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 69:c1:c7:a9:c3:c0, First: 332.811, Last: 656.216, Count: 242, Highest RSSI:-24, Lowest RSSI:-21 Label: Phone Scan
# Source: 6b:13:57:45:38:e8, First: 1.329, Last: 332.269, Count: 303, Highest RSSI:-24, Lowest RSSI:-21 Label: Phone Scan
# Source: 6c:ed:ed:bb:64:33, First: 19230.469, Last: 19576.934, Count: 157, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 6d:08:ac:a7:b2:fa, First: 19579.146, Last: 20066.109, Count: 227, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 6e:01:b2:89:f9:ef, First: 5121.313, Last: 5577.13, Count: 349, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 6e:0f:39:24:27:fd, First: 15835.423, Last: 16247.397, Count: 207, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 70:aa:b3:44:3f:61, First: 2264.809, Last: 2954.815, Count: 571, Highest RSSI:-28, Lowest RSSI:-22 Label: Phone Scan
# Source: 71:05:ef:cf:69:23, First: 3350.514, Last: 3731.417, Count: 268, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 71:7d:b0:81:59:56, First: 21064.37, Last: 21545.039, Count: 219, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 74:48:07:61:7d:d3, First: 1441.437, Last: 1916.069, Count: 296, Highest RSSI:-24, Lowest RSSI:-21 Label: Phone Scan
# Source: 76:25:e9:36:00:7a, First: 14631.847, Last: 15012.79, Count: 169, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 77:32:7f:bd:99:2d, First: 16745.567, Last: 17301.154, Count: 262, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 78:63:3e:c3:c0:d9, First: 10879.635, Last: 11313.574, Count: 234, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 7a:dc:44:bd:23:4c, First: 12413.311, Last: 12809.82, Count: 200, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 7b:94:9c:9d:b2:e5, First: 9668.988, Last: 10109.096, Count: 204, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 7c:81:b9:be:c0:ea, First: 4709.711, Last: 5118.854, Count: 374, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 7e:7e:88:76:d4:b9, First: 2956.321, Last: 3349.768, Count: 259, Highest RSSI:-25, Lowest RSSI:-22 Label: Phone Scan
# Source: 01:0c:7d:97:20:19, First: 20771.078, Last: 21331.746, Count: 1395, Highest RSSI:-55, Lowest RSSI:-42 Label: Phone Google
# Source: 01:5c:c9:b5:90:3f, First: 1276.842, Last: 1694.53, Count: 998, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 01:d3:f0:90:6b:db, First: 5144.966, Last: 5577.208, Count: 1031, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 02:4d:33:82:b9:bf, First: 10113.417, Last: 10481.237, Count: 869, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 02:78:e9:95:8a:12, First: 4359.045, Last: 4708.353, Count: 790, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 03:f0:06:5a:b1:f4, First: 15423.311, Last: 15833.681, Count: 969, Highest RSSI:-53, Lowest RSSI:-40 Label: Phone Google
# Source: 04:83:b8:84:41:05, First: 7609.548, Last: 7958.797, Count: 817, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 04:be:7f:a6:c6:ec, First: 16746.441, Last: 17095.586, Count: 873, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 06:6e:fc:44:59:4f, First: 5579.013, Last: 6052.594, Count: 1141, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 06:79:fc:68:9e:28, First: 9193.544, Last: 9668.205, Count: 1126, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 07:c7:f1:6a:e7:2c, First: 1695.57, Last: 2086.955, Count: 913, Highest RSSI:-48, Lowest RSSI:-41 Label: Phone Google
# Source: 08:d7:40:fa:37:0b, First: 17096.616, Last: 17648.273, Count: 1315, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 0a:d8:ec:33:82:4c, First: 14337.405, Last: 14714.225, Count: 911, Highest RSSI:-55, Lowest RSSI:-40 Label: Phone Google
# Source: 0c:14:f8:77:aa:c6, First: 6053.386, Last: 6390.166, Count: 778, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 0c:83:1a:2f:13:3a, First: 8451.665, Last: 8855.845, Count: 985, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 0d:fd:17:93:d1:c4, First: 11282.769, Last: 11820.622, Count: 1289, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 10:5a:f3:60:61:71, First: 21332.783, Last: 21671.316, Count: 831, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 12:a9:2a:cd:38:2c, First: 7959.835, Last: 8450.631, Count: 1134, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 15:0a:29:db:70:37, First: 18349.001, Last: 18815.317, Count: 1109, Highest RSSI:-56, Lowest RSSI:-40 Label: Phone Google
# Source: 15:7f:66:d0:60:0a, First: 4710.701, Last: 5143.934, Count: 1000, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 17:de:02:e3:72:d8, First: 14157.686, Last: 14336.547, Count: 431, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 1c:e6:28:e0:be:4a, First: 3735.145, Last: 4357.939, Count: 1464, Highest RSSI:-56, Lowest RSSI:-40 Label: Phone Google
# Source: 1d:86:94:6a:cb:c3, First: 19579.281, Last: 20068.324, Count: 1189, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 1d:e3:1a:df:04:d5, First: 19230.717, Last: 19578.988, Count: 854, Highest RSSI:-53, Lowest RSSI:-40 Label: Phone Google
# Source: 1f:44:3d:cb:64:a9, First: 10872.274, Last: 11281.732, Count: 931, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 1f:fb:7a:ca:55:6e, First: 13423.405, Last: 13782.268, Count: 803, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 24:89:8b:a0:d3:74, First: 17648.784, Last: 18347.164, Count: 1674, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 27:11:29:c2:0f:6b, First: 20419.748, Last: 20770.046, Count: 836, Highest RSSI:-52, Lowest RSSI:-42 Label: Phone Google
# Source: 27:f8:2e:5b:ba:b1, First: 13011.091, Last: 13422.371, Count: 1010, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 29:5f:58:88:c4:08, First: 7159.916, Last: 7607.671, Count: 1056, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 2b:5f:6f:4f:92:a6, First: 3351.52, Last: 3733.83, Count: 896, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 2b:d2:2b:75:20:cd, First: 8856.878, Last: 9191.555, Count: 779, Highest RSSI:-54, Lowest RSSI:-40 Label: Phone Google
# Source: 2d:33:a9:ae:a2:1d, First: 2087.992, Last: 2574.462, Count: 1139, Highest RSSI:-54, Lowest RSSI:-40 Label: Phone Google
# Source: 2d:8c:d6:0b:97:75, First: 18816.161, Last: 19229.748, Count: 1002, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 2e:12:dc:51:3e:5c, First: 11823.233, Last: 12412.858, Count: 1386, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 2e:81:84:84:d4:be, First: 6740.206, Last: 7158.852, Count: 1024, Highest RSSI:-53, Lowest RSSI:-40 Label: Phone Google
# Source: 2f:8d:3a:26:bb:7a, First: 2575.495, Last: 2955.873, Count: 899, Highest RSSI:-50, Lowest RSSI:-39 Label: Phone Google
# Source: 30:81:51:d4:3c:80, First: 2956.548, Last: 3349.317, Count: 983, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 31:d1:b9:a2:1f:15, First: 6391.2, Last: 6738.398, Count: 862, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 32:e3:20:74:34:ee, First: 0.073, Last: 370.386, Count: 891, Highest RSSI:-51, Lowest RSSI:-44 Label: Phone Google
# Source: 35:4b:3e:69:c0:b7, First: 10481.574, Last: 10871.23, Count: 921, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 36:a3:81:7e:f0:40, First: 16182.996, Last: 16744.924, Count: 1380, Highest RSSI:-54, Lowest RSSI:-40 Label: Phone Google
# Source: 37:c8:f7:f5:e6:e9, First: 9668.962, Last: 10111.471, Count: 1016, Highest RSSI:-53, Lowest RSSI:-40 Label: Phone Google
# Source: 39:92:7f:3e:7b:11, First: 14715.256, Last: 15422.18, Count: 1728, Highest RSSI:-53, Lowest RSSI:-40 Label: Phone Google
# Source: 39:e9:ee:d2:af:a0, First: 15835.809, Last: 16181.963, Count: 819, Highest RSSI:-52, Lowest RSSI:-40 Label: Phone Google
# Source: 3a:5f:8c:0c:2c:18, First: 13783.308, Last: 14156.649, Count: 889, Highest RSSI:-51, Lowest RSSI:-40 Label: Phone Google
# Source: 3b:a7:f0:4a:66:b7, First: 917.04, Last: 1275.816, Count: 784, Highest RSSI:-50, Lowest RSSI:-43 Label: Phone Google
# Source: 3d:fb:99:ec:bd:fa, First: 371.414, Last: 916.009, Count: 1263, Highest RSSI:-50, Lowest RSSI:-40 Label: Phone Google
# Source: 3e:e4:e0:e7:34:9c, First: 20069.132, Last: 20418.447, Count: 857, Highest RSSI:-54, Lowest RSSI:-42 Label: Phone Google
# Source: 3f:f9:a3:7e:3c:54, First: 12414.124, Last: 13010.051, Count: 1413, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Google
# Source: 40:6a:da:cb:83:4b, First: 17993.16, Last: 18348.145, Count: 5548, Highest RSSI:-59, Lowest RSSI:-41 Label: Phone Phone
# Source: 40:c4:04:c1:7a:84, First: 5121.337, Last: 5578.611, Count: 7147, Highest RSSI:-60, Lowest RSSI:-40 Label: Phone Phone
# Source: 43:8a:b9:59:93:4e, First: 3300.043, Last: 3660.001, Count: 5701, Highest RSSI:-62, Lowest RSSI:-42 Label: Phone Phone
# Source: 46:68:7a:22:3a:bf, First: 15439.369, Last: 15835.125, Count: 6144, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 47:ad:ae:62:d7:41, First: 2087.892, Last: 2575.072, Count: 7336, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 47:c3:5f:3a:54:0d, First: 12172.677, Last: 12584.482, Count: 6283, Highest RSSI:-57, Lowest RSSI:-40 Label: Phone Phone
# Source: 48:34:85:c7:ec:a9, First: 2956.244, Last: 3299.731, Count: 5538, Highest RSSI:-57, Lowest RSSI:-40 Label: Phone Phone
# Source: 48:d5:a8:e2:e3:37, First: 7050.478, Last: 7608.384, Count: 8807, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 48:fd:da:9f:83:21, First: 4709.739, Last: 5121.177, Count: 6368, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 49:1e:f5:31:ab:2d, First: 8451.632, Last: 8856.583, Count: 6418, Highest RSSI:-62, Lowest RSSI:-40 Label: Phone Phone
# Source: 4a:db:4b:83:7f:72, First: 12584.572, Last: 13010.461, Count: 6743, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 4d:19:b7:64:ac:ef, First: 11283.631, Last: 11821.505, Count: 8480, Highest RSSI:-61, Lowest RSSI:-40 Label: Phone Phone
# Source: 4f:a4:e1:e1:20:c9, First: 4358.753, Last: 4709.574, Count: 5327, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 50:d5:01:1e:3f:c7, First: 1284.79, Last: 1695.014, Count: 6338, Highest RSSI:-59, Lowest RSSI:-41 Label: Phone Phone
# Source: 57:35:95:96:8c:36, First: 14533.374, Last: 15017.423, Count: 7774, Highest RSSI:-59, Lowest RSSI:-40 Label: Phone Phone
# Source: 57:c7:65:b1:4d:d9, First: 3660.035, Last: 4358.602, Count: 10603, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 58:2a:97:25:79:42, First: 13010.577, Last: 13422.366, Count: 6306, Highest RSSI:-57, Lowest RSSI:-40 Label: Phone Phone
# Source: 5a:ac:31:4e:d0:40, First: 9669.036, Last: 10112.202, Count: 6705, Highest RSSI:-58, Lowest RSSI:-39 Label: Phone Phone
# Source: 5b:a1:18:4d:e6:14, First: 916.543, Last: 1284.612, Count: 5607, Highest RSSI:-61, Lowest RSSI:-40 Label: Phone Phone
# Source: 5b:ba:4c:53:e9:58, First: 19696.862, Last: 20117.037, Count: 6515, Highest RSSI:-57, Lowest RSSI:-41 Label: Phone Phone
# Source: 5c:06:f4:89:64:ad, First: 19230.518, Last: 19696.633, Count: 7458, Highest RSSI:-59, Lowest RSSI:-41 Label: Phone Phone
# Source: 5c:9d:1b:c6:92:cc, First: 8856.628, Last: 9192.411, Count: 5194, Highest RSSI:-59, Lowest RSSI:-40 Label: Phone Phone
# Source: 5e:04:b6:02:fb:fd, First: 10481.734, Last: 10871.681, Count: 5952, Highest RSSI:-57, Lowest RSSI:-40 Label: Phone Phone
# Source: 5e:e5:8b:10:dc:6a, First: 17096.463, Last: 17648.476, Count: 8598, Highest RSSI:-60, Lowest RSSI:-40 Label: Phone Phone
# Source: 5f:64:ab:81:68:b5, First: 46.242, Last: 396.004, Count: 5268, Highest RSSI:-59, Lowest RSSI:-40 Label: Phone Phone
# Source: 60:f1:b2:37:28:a6, First: 15835.525, Last: 16249.193, Count: 6545, Highest RSSI:-60, Lowest RSSI:-40 Label: Phone Phone
# Source: 60:f7:84:0a:ab:e9, First: 5578.996, Last: 6053.172, Count: 7405, Highest RSSI:-62, Lowest RSSI:-40 Label: Phone Phone
# Source: 62:13:08:c4:a6:88, First: 16745.615, Last: 17096.301, Count: 5674, Highest RSSI:-57, Lowest RSSI:-40 Label: Phone Phone
# Source: 63:c6:d6:6a:af:d4, First: 15017.728, Last: 15439.277, Count: 6711, Highest RSSI:-62, Lowest RSSI:-40 Label: Phone Phone
# Source: 64:7c:90:3f:8c:d3, First: 7959.778, Last: 8451.562, Count: 7444, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 66:0a:bc:01:7f:9b, First: 7608.804, Last: 7959.571, Count: 5455, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 66:ab:51:a2:a3:d4, First: 10112.456, Last: 10481.484, Count: 5456, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 6a:40:98:a9:65:ca, First: 18816.208, Last: 18837.542, Count: 341, Highest RSSI:-57, Lowest RSSI:-41 Label: Phone Phone
# Source: 6b:be:ef:d5:7b:09, First: 11821.834, Last: 12172.415, Count: 5434, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 6b:fc:0a:92:26:55, First: 17648.617, Last: 17992.983, Count: 5298, Highest RSSI:-58, Lowest RSSI:-38 Label: Phone Phone
# Source: 6e:0d:2e:1d:31:75, First: 9192.631, Last: 9668.837, Count: 7397, Highest RSSI:-59, Lowest RSSI:-40 Label: Phone Phone
# Source: 6f:83:da:40:c8:d3, First: 21332.609, Last: 21671.634, Count: 5257, Highest RSSI:-57, Lowest RSSI:-41 Label: Phone Phone
# Source: 6f:bf:c1:6e:b1:b6, First: 20117.157, Last: 20770.34, Count: 10232, Highest RSSI:-57, Lowest RSSI:-41 Label: Phone Phone
# Source: 6f:ce:44:ec:b1:b4, First: 13782.475, Last: 14157.436, Count: 6023, Highest RSSI:-61, Lowest RSSI:-40 Label: Phone Phone
# Source: 72:0d:5e:6e:1f:13, First: 1695.188, Last: 2087.616, Count: 6101, Highest RSSI:-57, Lowest RSSI:-41 Label: Phone Phone
# Source: 72:39:4f:dd:da:cc, First: 396.039, Last: 916.39, Count: 7914, Highest RSSI:-57, Lowest RSSI:-44 Label: Phone Phone
# Source: 72:56:57:e7:47:c8, First: 18837.956, Last: 19230.377, Count: 6121, Highest RSSI:-58, Lowest RSSI:-41 Label: Phone Phone
# Source: 74:20:d4:5e:ff:58, First: 18348.216, Last: 18815.437, Count: 7455, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 74:70:df:5b:5d:13, First: 0.0, Last: 46.065, Count: 794, Highest RSSI:-53, Lowest RSSI:-44 Label: Phone Phone
# Source: 74:88:e0:e6:07:70, First: 6053.443, Last: 6738.829, Count: 10758, Highest RSSI:-58, Lowest RSSI:-39 Label: Phone Phone
# Source: 74:ee:22:15:a1:70, First: 2575.244, Last: 2956.051, Count: 5914, Highest RSSI:-57, Lowest RSSI:-41 Label: Phone Phone
# Source: 75:c7:5b:a6:d7:bf, First: 14157.624, Last: 14533.294, Count: 5868, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 75:f4:7f:dd:b8:5a, First: 16249.423, Last: 16745.453, Count: 7850, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 76:ab:51:a2:a3:d4, First: 10151.951, Last: 10293.64, Count: 4, Highest RSSI:-44, Lowest RSSI:-43 Label: Phone Phone
# Source: 7a:6d:c4:a3:33:bf, First: 13422.625, Last: 13782.4, Count: 5511, Highest RSSI:-58, Lowest RSSI:-38 Label: Phone Phone
# Source: 7a:fd:e4:c4:92:e7, First: 6738.955, Last: 7050.356, Count: 4910, Highest RSSI:-58, Lowest RSSI:-40 Label: Phone Phone
# Source: 7d:34:f6:d0:0a:6e, First: 18815.619, Last: 18815.771, Count: 4, Highest RSSI:-49, Lowest RSSI:-46 Label: Phone Phone
# Source: 7e:4e:02:18:c8:a0, First: 20770.409, Last: 21332.442, Count: 8888, Highest RSSI:-58, Lowest RSSI:-41 Label: Phone Phone
# Source: 7f:47:2c:fd:3f:3c, First: 10871.877, Last: 11283.455, Count: 6199, Highest RSSI:-58, Lowest RSSI:-39 Label: Phone Phone
# --------------------------------------------------
# FINAL DATAFRAME
#
# Length Raw Dataframe: 2638741
# Length Final Dataframe: 2571127
# Removed: 67614, Diff: 67614

# %%
print(len(final_list))
# Out:
# 12855635
